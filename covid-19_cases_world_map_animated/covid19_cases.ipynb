# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('time_series_covid19_confirmed_global.csv')

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/27/20  3/28/20  3/29/20  3/30/20  \
# 0        0        0        0  ...      110      110      120      170
# 1        0        0        0  ...      186      197      212      223
# 2        0        0        0  ...      409      454      511      584
# 3        0        0        0  ...      267      308      334      370
# 4        0        0        0  ...        4        5        7        7
#
#    3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 79 columns):
# Province/State    82 non-null object
# Country/Region    262 non-null object
# Lat               262 non-null float64
# Long              262 non-null float64
# 1/22/20           262 non-null int64
# 1/23/20           262 non-null int64
# 1/24/20           262 non-null int64
# 1/25/20           262 non-null int64
# 1/26/20           262 non-null int64
# 1/27/20           262 non-null int64
# 1/28/20           262 non-null int64
# 1/29/20           262 non-null int64
# 1/30/20           262 non-null int64
# 1/31/20           262 non-null int64
# 2/1/20            262 non-null int64
# 2/2/20            262 non-null int64
# 2/3/20            262 non-null int64
# 2/4/20            262 non-null int64
# 2/5/20            262 non-null int64
# 2/6/20            262 non-null int64
# 2/7/20            262 non-null int64
# 2/8/20            262 non-null int64
# ...

# %%
df = df.drop(columns=['Province/State', 'Lat', 'Long'])

# %%
df.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  3/27/20  3/28/20  3/29/20  3/30/20  \
# 0        0        0        0  ...      110      110      120      170
# 1        0        0        0  ...      186      197      212      223
# 2        0        0        0  ...      409      454      511      584
# 3        0        0        0  ...      267      308      334      370
# 4        0        0        0  ...        4        5        7        7
#
#    3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# 0      174     237     273     281     299     349
# ...

# %%
df = df.melt(id_vars=['Country/Region'], 
        var_name='Date', 
        value_name='Cases')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19650 entries, 0 to 19649
# Data columns (total 3 columns):
# Country/Region    19650 non-null object
# Date              19650 non-null object
# Cases             19650 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 460.7+ KB

# %%
df.head()
# Out:
#   Country/Region     Date  Cases
# 0    Afghanistan  1/22/20      0
# 1        Albania  1/22/20      0
# 2        Algeria  1/22/20      0
# 3        Andorra  1/22/20      0
# 4         Angola  1/22/20      0

# %%
df = df[df['Cases'] != 0]

# %%
df.head()
# Out:
#    Country/Region     Date  Cases
# 49          China  1/22/20      1
# 50          China  1/22/20     14
# 51          China  1/22/20      6
# 52          China  1/22/20      1
# 54          China  1/22/20     26

# %%
df.Date.unique()
# Out:
# array(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20',
#        '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20',
#        '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20',
#        '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20',
#        '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20',
#        '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20',
#        '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20', '3/15/20',
#        '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20',
#        '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20', '3/27/20',
#        '3/28/20', '3/29/20', '3/30/20', '3/31/20', '4/1/20', '4/2/20',
#        '4/3/20', '4/4/20', '4/5/20'], dtype=object)

# %%
df['Total cases'] = df.groupby(['Country/Region', 'Date'])['Cases'].transform('sum')

# %%
df_new = df.drop_duplicates(subset=['Country/Region', 'Date'])

# %%
df_new.head()
# Out:
#     Country/Region     Date  Cases  Total cases
# 49           China  1/22/20      1          548
# 139          Japan  1/22/20      2            2
# 143   Korea, South  1/22/20      1            1
# 207        Taiwan*  1/22/20      1            1
# 209       Thailand  1/22/20      2            2

# %%
fig = px.scatter_geo(df_new, locations='Country/Region', locationmode='country names', hover_name='Country/Region',
color_discrete_sequence=px.colors.qualitative.Light24, projection='natural earth',
animation_frame='Date', size='Total cases', size_max=60, width=1000, height=720, title='COVID-19 cases from Jan 22nd to Apr 6th')
fig.show()
import plotly.io as pio
pio.write_html(fig, file='COVID-19_cases.html', auto_open=True)
# Out:
# <div>
#
#
#             <div id="975ed91f-22ff-4546-adab-246907aa8cb5" class="plotly-graph-div" style="height:720px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("975ed91f-22ff-4546-adab-246907aa8cb5")) {
#                     Plotly.newPlot(
#                         '975ed91f-22ff-4546-adab-246907aa8cb5',
# ...

# %%
df2 = pd.read_csv('time_series_covid19_confirmed_US.csv')

# %%
df2.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 3/27/20  3/28/20  3/29/20  3/30/20  3/31/20  4/1/20  \
# 0 -14.2710 -170.1320  ...       0        0        0        0        0       0
# 1  13.4443  144.7937  ...      51       55       56       58       69      77
# 2  15.0979  145.6739  ...       0        0        0        0        2       6
# 3  18.2208  -66.5901  ...      79      100      127      174      239     286
# 4  18.3358  -64.8963  ...      19       22        0        0       30      30
#
# ...

# %%
for x in df2.columns:
    if x != 'Country_Region' and x != 'Province_State' and x != '4/5/20' and x != 'Lat' and x != 'Long_' and x != 'FIPS':
        df2.drop(x, axis = 1, inplace=True)

# %%
df2.head()
# Out:
#    FIPS            Province_State Country_Region      Lat     Long_  4/5/20
# 0  60.0            American Samoa             US -14.2710 -170.1320       0
# 1  66.0                      Guam             US  13.4443  144.7937     112
# 2  69.0  Northern Mariana Islands             US  15.0979  145.6739       6
# 3  72.0               Puerto Rico             US  18.2208  -66.5901     475
# 4  78.0            Virgin Islands             US  18.3358  -64.8963      42

# %%
df2.rename(columns={'4/5/20' : 'Cases'}, inplace=True)

# %%
df2 = df2[df2['Cases'] != 0]

# %%
px.set_mapbox_access_token(open(".mapbox_token").read())
fig = px.scatter_mapbox(df2, lat='Lat', lon='Long_', size='Cases',
        size_max=80, zoom=3.5, mapbox_style='light', center = {'lat': 37.0902, 'lon': -95.7129},
        color_discrete_sequence=['red'], width=1280, height=720,
        hover_data=['Province_State', 'Lat', 'Long_', 'Cases']
                       )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
pio.write_html(fig, file='COVID-19_cases_USA.html', auto_open=True)
# Out:
# <div>
#
#
#             <div id="5de391b3-e1d3-4872-9242-a1dba6f68c19" class="plotly-graph-div" style="height:720px; width:1280px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5de391b3-e1d3-4872-9242-a1dba6f68c19")) {
#                     Plotly.newPlot(
#                         '5de391b3-e1d3-4872-9242-a1dba6f68c19',
# ...
